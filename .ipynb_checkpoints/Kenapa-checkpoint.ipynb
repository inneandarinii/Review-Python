# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.9 MB 7.8 MB/s eta 0:00:02
#    ------ --------------------------------- 1.6/9.9 MB 4.7 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/9.9 MB 4.3 MB/s eta 0:00:02
#    -------------- ------------------------- 3.7/9.9 MB 4.9 MB/s eta 0:00:02
#    ------------------ --------------------- 4.5/9.9 MB 4.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.8/9.9 MB 4.9 MB/s eta 0:00:01
#    --------------------------- ------------ 6.8/9.9 MB 5.0 MB/s eta 0:00:01
#    -------------------------------- ------- 8.1/9.9 MB 5.1 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.9 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 5.0 MB/s  0:00:02
# ...

# %% [markdown]
# ## Pandas

# %% [markdown]
# ## 1. Pengenalan Pandas
# Pandas digunakan untuk analisis data terstruktur

# %%
import pandas as pd

# %% [markdown]
# ![image.png](attachment:b9508c75-6843-4f80-be91-fd0352c70dda.png)

# %%
# Series 
nama = ['inne', 'andarini', 'herdianti']
nama_series = pd.Series(nama)
nama_series
# Out:
# 0         inne
# 1     andarini
# 2    herdianti
# dtype: str

# %%
#DataFrame
members = {'nama': ['inne', 'andarini', 'herdianti'],
           'umur': [24,25,26]}
members_df = pd.DataFrame(members)
members_df
# Out:
#         nama  umur
# 0       inne    24
# 1   andarini    25
# 2  herdianti    26

# %% [markdown]
# # Import data dari File
